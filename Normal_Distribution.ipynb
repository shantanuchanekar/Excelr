# %% [markdown]
# <a href="https://colab.research.google.com/github/shantanuchanekar/Excelr/blob/main/Normal_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import stats

# %%
1-stats.norm.cdf(720,711,29)
# Out:
# 0.37814937265194704

# %%
1-stats.norm.cdf(60,50,5)
# Out:
# 0.02275013194817921

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0cc25202-5749-46dd-9fd2-342fe088b75f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cc25202-5749-46dd-9fd2-342fe088b75f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
beml_df = pd.read_csv('BEML.csv')
beml_df.head()
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              101651.0          1157.18
# 1               59504.0           676.47
# 2              128908.0          1482.84
# 3              117871.0          1352.98
# 4              170063.0          1971.42

# %%
gl_df = pd.read_csv('GLAXO.csv')
gl_df.head()
# Out:
#          Date     Open     High      Low    Last    Close  \
# 0  2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1  2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2  2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3  2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4  2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                9365.0           151.74
# 1               38148.0           622.58
# 2               36519.0           595.09
# 3               12809.0           211.00
# 4               28035.0           459.11

# %%
gl_df = gl_df[['Date','Close']]
beml_df = beml_df[['Date','Close']]

# %%
gl_df.head()
# Out:
#          Date    Close
# 0  2010-01-04  1625.65
# 1  2010-01-05  1616.80
# 2  2010-01-06  1638.50
# 3  2010-01-07  1648.70
# 4  2010-01-08  1639.80

# %%
beml_df.head()
# Out:
#          Date    Close
# 0  2010-01-04  1135.60
# 1  2010-01-05  1134.60
# 2  2010-01-06  1139.60
# 3  2010-01-07  1144.15
# 4  2010-01-08  1144.05

# %%
beml_df['Date'] = pd.to_datetime(beml_df['Date'])
beml_df.dtypes
# Out:
# Date     datetime64[ns]
# Close           float64
# dtype: object

# %%
gl_df = gl_df.set_index(pd.DatetimeIndex(gl_df['Date'])).drop('Date',axis=1)
beml_df = beml_df.set_index(pd.DatetimeIndex(beml_df['Date'])).drop('Date',axis=1)

# %%
gl_df.head()
# Out:
#               Close
# Date
# 2010-01-04  1625.65
# 2010-01-05  1616.80
# 2010-01-06  1638.50
# 2010-01-07  1648.70
# 2010-01-08  1639.80

# %%
beml_df.head()
# Out:
#               Close
# Date
# 2010-01-04  1135.60
# 2010-01-05  1134.60
# 2010-01-06  1139.60
# 2010-01-07  1144.15
# 2010-01-08  1144.05

# %%
beml_df.dtypes
# Out:
# Close    float64
# dtype: object
