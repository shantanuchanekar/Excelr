# %% [markdown]
# <a href="https://colab.research.google.com/github/shantanuchanekar/Excelr/blob/main/Sallary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3bab16c4-a780-4452-ab29-d9899bf4b52b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3bab16c4-a780-4452-ab29-d9899bf4b52b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Salaries.csv")

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
size=df.size

# %%
col=df.columns
print(col)
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
col_len=len(col)
print("No. of columns: ",col_len)
# Out:
# No. of columns:  6

# %%
rec_len=size/6
print(rec_len)
# Out:
# 78.0

# %%
dataTypes=df.dtypes
print(dataTypes)
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.std()
# Out:
# <ipython-input-9-ce97bb7eaef8>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.head(50).mean()
# Out:
# <ipython-input-12-56442511a41d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.head(50).mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-25-c61f0c8f89b5>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.ndim
# Out:
# 2

# %%
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.phd.count()
# Out:
# 78

# %%
df.phd.mean()
# Out:
# 19.705128205128204

# %%
rnk_grp=df.groupby(['rank'])
rnk_grp.mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
des_grp=df.groupby(['discipline'])
des_grp.max()
# Out:
#             rank  phd  service   sex  salary
# discipline
# A           Prof   51       51  Male  155865
# B           Prof   56       49  Male  186960

# %%
df.groupby(['rank']).mean().iloc[:, 0:1]
# Out:
#                  phd
# rank
# AssocProf  15.076923
# AsstProf    5.052632
# Prof       27.065217

# %%
df.groupby('discipline')[['service']].mean()
# Out:
#               service
# discipline
# A           15.722222
# B           14.476190

# %%
df.groupby(['sex'])[['salary']].max()
# Out:
#         rank discipline  phd  service  salary
# sex
# Female  Prof          B   39       36  161101
# Male    Prof          B   56       51  186960

# %%
df[df['salary']>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
sal=df[df['salary']<130000]

# %%
sal
# Out:
#          rank discipline  phd  service     sex  salary
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [62 rows x 6 columns]

# %%
df[(df['salary']>=100000)&(df['salary']<=180000)&(df['rank']=='AssocProf')&(df['sex']=='Female')]
# Out:
#          rank discipline  phd  service     sex  salary
# 47  AssocProf          B   11       11  Female  103613
# 59  AssocProf          B   12       10  Female  103994
# 61  AssocProf          B   13       10  Female  103750
# 62  AssocProf          B   14        7  Female  109650
# 74  AssocProf          B   19        6  Female  104542

# %%
pd.set_option('display.max_rows',7)

# %%
df
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 1   Prof          A   12        6    Male   93000
# 2   Prof          A   23       20    Male  110515
# ..   ...        ...  ...      ...     ...     ...
# 75  Prof          B   17       17  Female  124312
# 76  Prof          A   28       14  Female  109954
# 77  Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.iloc[0:3]
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515

# %%
df.iloc[:,-2:6]
# Out:
#        sex  salary
# 0     Male  186960
# 1     Male   93000
# 2     Male  110515
# 3     Male  131205
# 4     Male  104800
# ..     ...     ...
# 73  Female  105450
# 74  Female  104542
# 75  Female  124312
# 76  Female  109954
# 77  Female  109646
#
# [78 rows x 2 columns]

# %%
print("Avg sallary of prof is:", df[df['rank']=='Prof']['salary'].mean())
# Out:
# Avg sallary of prof is: 123624.80434782608

# %%
print('No. of male Prof',df[(df['rank']=='Prof')&(df['sex']=='Male')]['sex'].count())
# Out:
# No. of male Prof 28
